# %% [markdown]
# # **La Transformación del Mundo en los Últimos 60 Años**

# %% [markdown]
# Curso:   Data Science\
# Tutor:   María Freidberger\
# Alumno:  Karim Singer
#
# ### Dataset elegido:
#   **'world_development_indicators_1960-2023.csv'** (Fuente: https://databank.worldbank.org/source/world-development-indicators)
#
# Sobre el dataset:
#
#   El data set fue creado a partir de la base de datos públicos del **World Bank**, una plataforma que permite crear datasets a partir de una base de 85 Databases disponibles. En este caso la elección fue **"World Develpment Indicators"**. Este dataset contiene **1492 'series' (variables)**, estas variables están separadas por categorías y en este dataset usé la categoría de **"Enviropment"(Medio Ambiente)** y de las cuales inicialmente **seleccioné 59 variables**. Esta selección fue aplicada al total disponible de **266 países o entidades** (entidades tales como "World", "OCDE", etc.) y con la **serie de tiempo total disponible (1960-2023)**.|
#
#   Algo interesante de este dataset es la posibilidad de ir enriqueciéndolo a través de su API con nuevas variables a medida que avance la exploración. Por ejemplo, eventualmente podríamos agregar variables tales como *Cambio Climático* o *Proyecciones de crecimiento*.

# %% [markdown]
# ### Abstract:
#
# En este proyecto de investigación, exploraremos la evolución de varios indicadores clave a lo largo de los últimos 60 años, desde 1960 hasta 2023. Utilizaremos un conjunto de datos recopilado del sitio de The World Bank Data.
#
# Este conjunto de datos abarca una variedad de aspectos, incluidos la pesca, la tierra de cultivo, la población, la producción de gas y carbón, el uso de energía, el PIB per cápita, el uso de agua dulce,  las tierras agrícolas, la producción de petróleo, la producción de cereales, las emisiones de CO2, entre otros. A través de un análisis exploratorio de datos y técnicas de visualización, buscaremos identificar tendencias, patrones y posibles relaciones entre estos indicadores a lo largo del tiempo.
#
# En resumen, este proyecto representa un esfuerzo por comprender mejor la dinámica compleja y multifacética de cómo nuestro mundo ha cambiado en las últimas seis décadas, utilizando herramientas y técnicas del campo de la ciencia de datos.

# %% [markdown]
# ## Hipótesis
#
#
# Basándonos en la información proporcionada por el conjunto de datos, podemos plantear algunas hipótesis iniciales:
#    - El consumo de energía, habrá experimentado un aumento significativo a lo largo de los años debido al crecimiento industrial y poblacional.
#
#    - Las emisiones de CO2 estarán correlacionadas con el uso de energía y la producción industrial, mostrando un aumento progresivo a lo largo del tiempo.
#
#    - El uso de agua dulce y la tierra de cultivo pueden estar influenciados por cambios en la agricultura y la demanda de alimentos.

# %% [markdown]
# ## Preguntas exploratorias:
#
# Algunas preguntas que podríamos plantear para guiar nuestro análisis exploratorio de datos son:
#
#    - ¿Cuál ha sido la tendencia general en la producción de energía (gas, carbón, petróleo) en las últimas seis décadas?
#
#    - ¿Cómo ha evolucionado la población mundial y su distribución geográfica en este período de tiempo?
#
#    - ¿Cómo ha variado el uso de agua dulce y la tierra de cultivo en relación con el aumento de la producción agrícola y las necesidades alimentarias?
#
#    - ¿Hay alguna correlación entre el crecimiento económico (medido por el PIB per cápita) y la producción de energía, la producción agrícola y las emisiones de CO2?
#
#    - ¿Cómo ha impactado en las zonas de bosque, el avance de las tierras para cultivo y ganado?

# %% [markdown]
# ### **Storytelling**
#
#
# **El asombroso cambio de nuestro mundo en las últimas seis décadas**
#
# Vivimos en una era de transformaciones vertiginosas, donde el ritmo del cambio parece superar incluso a las épocas más dinámicas de la historia humana. La última mitad del siglo XX y los primeros años del siglo XXI han sido testigos de una revolución sin precedentes que ha remodelado nuestro planeta en formas inimaginables. Nos encontramos en un punto donde la velocidad y la magnitud de la transformación desafían nuestra capacidad para comprenderla plenamente.
#
# Durante siglos, la humanidad navegó a través del río del tiempo en un curso relativamente constante. Sin embargo, todo cambió con el advenimiento de la industrialización y la globalización. Estos fenómenos no solo aceleraron el progreso humano, sino que también alteraron profundamente la estructura misma de nuestras sociedades y la forma en que interactuamos con el mundo que nos rodea.
#
# Uno de los aspectos más sorprendentes de esta transformación es la explosión de información que presenciamos en los últimos años. Para ponerlo en perspectiva, basta considerar que en un solo día actual generamos más datos que los acumulados a lo largo de toda la historia humana hasta hace apenas unas décadas. Este aluvión de información, alimentado por avances tecnológicos sin precedentes, ha desencadenado cambios sísmicos en la forma en que vivimos, trabajamos y nos relacionamos entre nosotros.
#
# Pero, ¿cómo ha sido posible este cambio tan radical? Los motores principales son múltiples y complejos. La industrialización, con su capacidad para impulsar la producción a niveles nunca antes vistos, ha sido un motor fundamental de este proceso. La globalización, por su parte, ha derribado barreras geográficas y culturales, creando un mundo más interconectado que nunca. La convergencia de la tecnología, la comunicación instantánea y la movilidad global ha generado un entorno donde las ideas y la innovación pueden fluir libremente, dando lugar a avances asombrosos en todas las áreas de la vida humana.
#
# Sin embargo, este cambio no ha sido uniforme ni equitativo. A medida que el mundo se transforma, surgen desafíos nuevos y urgentes. La desigualdad económica, la degradación ambiental y la crisis de identidad cultural son solo algunas de las fuerzas que moldean el paisaje de nuestro mundo en evolución.
#
# A medida que exploramos este vasto y complejo panorama de cambio, surge una pregunta fundamental: ¿cómo podemos navegar por este nuevo mundo de manera que promueva la prosperidad y el bienestar para todos? En el corazón de esta pregunta yace una oportunidad única para reflexionar sobre nuestro pasado, comprender nuestro presente y forjar un futuro que refleje nuestros valores más profundos y aspiraciones más nobles.
#
# Bienvenidos a un viaje de descubrimiento y reflexión. Bienvenidos a la historia del mundo en los últimos 60 años.
#
# ____________________________________________________________________________________

# %% [markdown]
# ### Primeros Pasos:
#
# Lo primero que haremos será cargar las librerías necesarias para el proyecto y luego cargar la base de datos.

# %%
# Importado de librerías 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
import missingno as msno
from datetime import datetime
import plotly.express as px

# %%
# Carga del dataset, bajo el nombre de 'df'

df = pd.read_csv('/home/karim/Desktop/Data Science/Coderhouse/Coderhouse_Data_Science/world_development_indicator_1960-2023.csv')

# %% [markdown]
# ### Revisión del dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17029 entries, 0 to 17028
# Data columns (total 63 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   Country Name                                                                                          17026 non-null  object
#  1   Country Code                                                                                          17024 non-null  object
#  2   Time                                                                                                  17024 non-null  float64
#  3   Time Code                                                                                             17024 non-null  object
# ...

# %% [markdown]
# **El dataset cuenta con 17.029 registros (filas) y 63 campos (columnas), los 4 primeros campos corresponden al País o entidad y su código, los años y su cógigo. Los otros 59 campos son las variables elegidas.**

# %%
df.head() # imprimir los 5 primeros registros
# Out:
#   Country Name Country Code    Time Time Code  \
# 0  Afghanistan          AFG  1960.0    YR1960
# 1  Afghanistan          AFG  1961.0    YR1961
# 2  Afghanistan          AFG  1962.0    YR1962
# 3  Afghanistan          AFG  1963.0    YR1963
# 4  Afghanistan          AFG  1964.0    YR1964
#
#   Access to clean fuels and technologies for cooking (% of population) [EG.CFT.ACCS.ZS]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to electricity (% of population) [EG.ELC.ACCS.ZS]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# ...

# %% [markdown]
# Todo bien, los 5 primeros registros corresponden a Afganistan (primer país por orden alfabético) y a los 5 primeros años de registros 1960 a 65
#
# **Observación:** Veo que los años están con decimal, lo que confirmo al mirar el .info() de arriba que muestra la columna 'Time' está como tipo float. En el EDA ajustaré eso para dejarlo como valor entero (integer)

# %%
df.tail() # imprimir los 5 últimos registros
# Out:
#                                            Country Name Country Code  Time  \
# 17024                                               NaN          NaN   NaN
# 17025                                               NaN          NaN   NaN
# 17026                                               NaN          NaN   NaN
# 17027  Data from database: World Development Indicators          NaN   NaN
# 17028                          Last Updated: 03/28/2024          NaN   NaN
#
#       Time Code  \
# 17024       NaN
# 17025       NaN
# 17026       NaN
# 17027       NaN
# 17028       NaN
#
#       Access to clean fuels and technologies for cooking (% of population) [EG.CFT.ACCS.ZS]  \
# 17024                                                NaN
# 17025                                                NaN
# 17026                                                NaN
# 17027                                                NaN
# 17028                                                NaN
#
# ...

# %% [markdown]
# Al revisar los últimos 5 registros me llama la atención los registros del campo 'Country Name', que no corresponden ni a país ni entidad. Ampliaré el número de registros a mostrar para explorar más.

# %%
df.tail(20) # imprimir los 20 últimos registros
# Out:
#                                            Country Name Country Code    Time  \
# 17009                                             World          WLD  2009.0
# 17010                                             World          WLD  2010.0
# 17011                                             World          WLD  2011.0
# 17012                                             World          WLD  2012.0
# 17013                                             World          WLD  2013.0
# 17014                                             World          WLD  2014.0
# 17015                                             World          WLD  2015.0
# 17016                                             World          WLD  2016.0
# 17017                                             World          WLD  2017.0
# 17018                                             World          WLD  2018.0
# 17019                                             World          WLD  2019.0
# ...

# %% [markdown]
# Ahora con esta visualización mayor, puedo ver que el último registro real corresponde a la entidad "World" (Mundo) con el registro 17023, por lo tanto, debería descartar las últimas 5 filas, para no afectar el análisis. Todo esto lo haré en la siguiente sección.

# %% [markdown]
# ----------------------------------------------------
# # **Análisis Exploratorio de Datos (EDA)**
#
# El Analisis exploratorio de datos o EDA por sus siglas en inglés Ues una etapa crucial en el proceso de análisis de datos, donde se examinan y se exploran los datos de manera sistemática para comprender su estructura, patrones, distribuciones y relaciones. Para esto, usaremos técnicas estadísticas y visuales para resumir y visualizar los datos, identificar valores atípicos, evaluar la calidad de los datos. El objetivo principal del EDA es obtener una comprensión profunda y significativa de los datos antes de aplicar modelos estadísticos o algoritmos de aprendizaje automático.

# %%
# Comienzo eliminando las últimas 5 filas, para dejar los registros sólo hasta el 17023

df = df.drop(df.tail(5).index)
df.tail() # imprimo para ver que haya sido bien eliminado
# Out:
#       Country Name Country Code    Time Time Code  \
# 17019        World          WLD  2019.0    YR2019
# 17020        World          WLD  2020.0    YR2020
# 17021        World          WLD  2021.0    YR2021
# 17022        World          WLD  2022.0    YR2022
# 17023        World          WLD  2023.0    YR2023
#
#       Access to clean fuels and technologies for cooking (% of population) [EG.CFT.ACCS.ZS]  \
# 17019                                   68.9184683287655
# 17020                                   70.1823413944676
# 17021                                   71.3298026968713
# 17022                                                 ..
# 17023                                                 ..
#
#       Access to electricity (% of population) [EG.ELC.ACCS.ZS]  \
# 17019                                   90.1935622398675
# 17020                                   90.4827030768684
# 17021                                   91.4140956410301
# ...

# %%
# Vuelvo a aplicar .info() para ver algunos detalles del dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17024 entries, 0 to 17023
# Data columns (total 63 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   Country Name                                                                                          17024 non-null  object
#  1   Country Code                                                                                          17024 non-null  object
#  2   Time                                                                                                  17024 non-null  float64
#  3   Time Code                                                                                             17024 non-null  object
# ...

# %% [markdown]
# **Observación:** algo que me llama la atención, es que no aparecen valores perdidos o nulos según esto, pero visualmente sé que sí los hay. Haré una impresión visual de los datos para ver esto.

# %%
"""
Los valores nulos no se reflejan porque están expresados como '..' para poder visualizarlos, cambiaré todos los .. por nan (not a number)
"""

df = df.replace({'..': np.nan}) 
df.info() # Nuevamente imprimo para ver si ahora se reflejan
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17024 entries, 0 to 17023
# Data columns (total 63 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   Country Name                                                                                          17024 non-null  object
#  1   Country Code                                                                                          17024 non-null  object
#  2   Time                                                                                                  17024 non-null  float64
#  3   Time Code                                                                                             17024 non-null  object
# ...

# %%
# Exploración visual de los valores nulos (misssing values)

msno.matrix(df, labels=True)
# Out:
# <Axes: >

# %% [markdown]
# **Observación 1:** ahora sí se ven los datos nulos.
#
# **Observación 2:** Los nombres de las columnas están muy extensos, debo darles nombres nuevos.

# %%
'''
Voy a ver los valores presentes por cada variable, ordenado de manera ascendente, con esta información, más adelante podría decidir eliminar las variables que tengan significativamente pocos datos (por ejemplo, menos de 2.000).
'''

# Exploración valores presentes


df.notnull().sum().sort_values(ascending = True)
# Out:
# Droughts, floods, extreme temperatures (% of population, average 1990-2009) [EN.CLC.MDAT.ZS]      168
# Mammal species, threatened [EN.MAM.THRD.NO]                                                       263
# Fish species, threatened [EN.FSH.THRD.NO]                                                         263
# Plant species (higher), threatened [EN.HPT.THRD.NO]                                               263
# Bird species, threatened [EN.BIR.THRD.NO]                                                         263
#                                                                                                 ...
# Population, total [SP.POP.TOTL]                                                                 16665
# Time                                                                                            17024
# Country Code                                                                                    17024
# ...

# %%
'''
Renombraré las variables, con etiquetas en español, cortas y precisas.
'''

nombres_nuevos = {
    'Country Name': 'Pais',
    'Country Code': 'Pais_Cod',
    'Time': 'Anio',
    'Time Code': 'Anio_Cod',
    'Access to clean fuels and technologies for cooking (% of population) [EG.CFT.ACCS.ZS]': 'Acceso a Cocina Limpia (% poblacion)',
    'Access to electricity (% of population) [EG.ELC.ACCS.ZS]': 'Acceso a Electricidad (% poblacion)',
    'Agricultural irrigated land (% of total agricultural land) [AG.LND.IRIG.AG.ZS]': 'Tierra Agricola Irrigada (% tierra agricola)',
    'Agricultural land (% of land area) [AG.LND.AGRI.ZS]': 'Tierra Agricola (% area terrestre)',
    'Agricultural land (sq. km) [AG.LND.AGRI.K2]': 'Tierra Agricola (km2)',
    'Agricultural methane emissions (% of total) [EN.ATM.METH.AG.ZS]': 'Emisiones de Metano Agricola (% total)',
    'Agricultural methane emissions (thousand metric tons of CO2 equivalent) [EN.ATM.METH.AG.KT.CE]': 'Emisiones de Metano Agricola (kton CO2eq)',
    'Agricultural nitrous oxide emissions (% of total) [EN.ATM.NOXE.AG.ZS]': 'Emisiones de Oxido Nitroso Agricola (% total)',
    'Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent) [EN.ATM.NOXE.AG.KT.CE]': 'Emisiones de Oxido Nitroso Agricola (kton CO2eq)',
    'Alternative and nuclear energy (% of total energy use) [EG.USE.COMM.CL.ZS]': 'Energia Alternativa y Nuclear (% uso energia)',
    'Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal) [ER.H2O.FWAG.ZS]': 'Extraccion Anual de Agua Dulce, Agricultura (% total extraccion agua dulce)',
    'Annual freshwater withdrawals, domestic (% of total freshwater withdrawal) [ER.H2O.FWDM.ZS]': 'Extraccion Anual de Agua Dulce, Domestica (% total extraccion agua dulce)',
    'Annual freshwater withdrawals, industry (% of total freshwater withdrawal) [ER.H2O.FWIN.ZS]': 'Extraccion Anual de Agua Dulce, Industria (% total extraccion agua dulce)',
    'Annual freshwater withdrawals, total (% of internal resources) [ER.H2O.FWTL.ZS]': 'Extraccion Anual de Agua Dulce, Total (% recursos internos)',
    'Annual freshwater withdrawals, total (billion cubic meters) [ER.H2O.FWTL.K3]': 'Extraccion Anual de Agua Dulce, Total (km3)',
    'Arable land (% of land area) [AG.LND.ARBL.ZS]': 'Tierra Arable (% area terrestre)',
    'Aquaculture production (metric tons) [ER.FSH.AQUA.MT]': 'Produccion de Acuicultura (ton Metricas)',
    'Arable land (hectares per person) [AG.LND.ARBL.HA.PC]': 'Tierra Arable (ha por persona)',
    'Arable land (hectares) [AG.LND.ARBL.HA]': 'Tierra Arable (ha)',
    'Average precipitation in depth (mm per year) [AG.LND.PRCP.MM]': 'Precipitacion Promedio (mm por ano)',
    'Bird species, threatened [EN.BIR.THRD.NO]': 'Especies de Aves Amenazadas',
    'Capture fisheries production (metric tons) [ER.FSH.CAPT.MT]': 'Produccion de Pesca de Captura (ton Metricas)',
    'Cereal production (metric tons) [AG.PRD.CREL.MT]': 'Produccion de Cereales (ton Metricas)',
    'Cereal yield (kg per hectare) [AG.YLD.CREL.KG]': 'Rendimiento de Cereales (kg por ha)',
    'CO2 emissions (kt) [EN.ATM.CO2E.KT]': 'Emisiones de CO2 (kton)',
    'CO2 emissions (metric tons per capita) [EN.ATM.CO2E.PC]': 'Emisiones de CO2 per capita (ton)',
    'Droughts, floods, extreme temperatures (% of population, average 1990-2009) [EN.CLC.MDAT.ZS]': 'Sequias, Inundaciones, Temperaturas Extremas (% poblacion, promedio 1990-2009)',
    'Electric power consumption (kWh per capita) [EG.USE.ELEC.KH.PC]': 'Consumo de Energia Electrica (kWh per capita)',
    'Energy use (kg of oil equivalent per capita) [EG.USE.PCAP.KG.OE]': 'Uso de Energia (kg de equivalente de petroleo per capita)',
    'Fertilizer consumption (% of fertilizer production) [AG.CON.FERT.PT.ZS]': 'Consumo de Fertilizantes (% produccion de fertilizantes)',
    'Fertilizer consumption (kilograms per hectare of arable land) [AG.CON.FERT.ZS]': 'Consumo de Fertilizantes (kg por ha de tierra arable)',
    'Fish species, threatened [EN.FSH.THRD.NO]': 'Especies de Peces Amenazadas',
    'Forest area (% of land area) [AG.LND.FRST.ZS]': 'Area de Bosque (% area terrestre)',
    'Forest area (sq. km) [AG.LND.FRST.K2]': 'Area de Bosque (km2)',
    'Fossil fuel energy consumption (% of total) [EG.USE.COMM.FO.ZS]': 'Consumo de Energia de Combustibles Fosiles (% total)',
    'Land area (sq. km) [AG.LND.TOTL.K2]': 'Area de Tierra (km2)',
    'Land under cereal production (hectares) [AG.LND.CREL.HA]': 'Tierra bajo Produccion de Cereales (ha)',
    'Mammal species, threatened [EN.MAM.THRD.NO]': 'Especies de Mamiferos Amenazadas',
    'Methane emissions (kt of CO2 equivalent) [EN.ATM.METH.KT.CE]': 'Emisiones de Metano (kton CO2eq)',
    'Plant species (higher), threatened [EN.HPT.THRD.NO]': 'Especies de Plantas Amenazadas',
    'PM2.5 air pollution, mean annual exposure (micrograms per cubic meter) [EN.ATM.PM25.MC.M3]': 'Contaminacion del Aire PM2.5, Exposicion Anual Promedio (ug/m3)',
    'Population density (people per sq. km of land area) [EN.POP.DNST]': 'Densidad de Poblacion (personas por km2)',
    'Population in largest city [EN.URB.LCTY]': 'Poblacion en la Ciudad Mas Grande',
    'Population in the largest city (% of urban population) [EN.URB.LCTY.UR.ZS]': 'Poblacion en la Ciudad Mas Grande (% poblacion urbana)',
    'Renewable energy consumption (% of total final energy consumption) [EG.FEC.RNEW.ZS]': 'Consumo de Energia Renovable (% total consumo final de energia)',
    'Rural land area (sq. km) [AG.LND.TOTL.RU.K2]': 'Area de Tierra Rural (km2)',
    'Rural population [SP.RUR.TOTL]': 'Poblacion Rural',
    'Rural population (% of total population) [SP.RUR.TOTL.ZS]': 'Poblacion Rural (% poblacion total)',
    'Rural population growth (annual %) [SP.RUR.TOTL.ZG]': 'Crecimiento de la Poblacion Rural (anual %)',
    'Surface area (sq. km) [AG.SRF.TOTL.K2]': 'Area de Superficie (km2)',
    'Terrestrial and marine protected areas (% of total territorial area) [ER.PTD.TOTL.ZS]': 'Areas Protegidas Terrestres y Marinas (% area territorial total)',
    'Terrestrial protected areas (% of total land area) [ER.LND.PTLD.ZS]': 'Areas Protegidas Terrestres (% area de tierra total)',
    'Total fisheries production (metric tons) [ER.FSH.PROD.MT]': 'Produccion Total de Pesca (ton Metricas)',
    'Total greenhouse gas emissions (kt of CO2 equivalent) [EN.ATM.GHGT.KT.CE]': 'Emisiones Totales de Gases de Efecto Invernadero (kton CO2eq)',
    'Urban land area (sq. km) [AG.LND.TOTL.UR.K2]': 'Area de Tierra Urbana (km2)',
    'Urban population [SP.URB.TOTL]': 'Poblacion Urbana',
    'Urban population (% of total population) [SP.URB.TOTL.IN.ZS]': 'Poblacion Urbana (% poblacion total)',
    'Urban population growth (annual %) [SP.URB.GROW]': 'Crecimiento de la Poblacion Urbana (anual %)',
    'Population, total [SP.POP.TOTL]': 'Poblacion Total'
}

# %%
# Renombro las columnas siguiento los nombres configurados.

df.rename(columns=nombres_nuevos, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17024 entries, 0 to 17023
# Data columns (total 63 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Pais                                                                            17024 non-null  object
#  1   Pais_Cod                                                                        17024 non-null  object
#  2   Anio                                                                            17024 non-null  float64
#  3   Anio_Cod                                                                        17024 non-null  object
#  4   Acceso a Cocina Limpia (% poblacion)                                            5214 non-null   object
#  5   Acceso a Electricidad (% poblacion)                                             7348 non-null   object
# ...

# %%
df.Anio.head()
# Out:
# 0    1960.0
# 1    1961.0
# 2    1962.0
# 3    1963.0
# 4    1964.0
# Name: Anio, dtype: float64

# %%
''' 
Cambio los tipos de las variables. 
'''

# Convertir todas las columnas a tipo float
columns_to_convert = df.columns.difference(['Pais', 'Pais_Cod', 'Anio', 'Anio_Cod'])
df[columns_to_convert] = df[columns_to_convert].astype(float)

# Convertir la columna 'Tiempo' a tipo integer
df['Anio'] = df['Anio'].astype(int)

# Verificar la transformación
df.dtypes
# Out:
# Pais                                             object
# Pais_Cod                                         object
# Anio                                              int64
# Anio_Cod                                         object
# Acceso a Cocina Limpia (% poblacion)            float64
#                                                  ...
# Area de Tierra Urbana (km2)                     float64
# Poblacion Urbana                                float64
# Poblacion Urbana (% poblacion total)            float64
# Crecimiento de la Poblacion Urbana (anual %)    float64
# Poblacion Total                                 float64
# Length: 63, dtype: object

# %%
'''
Conocer los paises y entidades incluidos en el dataset, con el objetivo de ver cómo puedo usar esta información para explorar mejor los valore nulos además de orientar mejor el análisis
'''

# Obtener cada país o entidad como valor único en la columna de países
paises = df['Pais'].unique()

# Imprimir los valores distintos
print(f'El total de entidades en el df es de: {len(paises)}', '\n')

print(paises)
# Out:
# El total de entidades en el df es de: 266
#
# ['Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahamas, The' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus'
#  'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan' 'Bolivia'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'British Virgin Islands'
#  'Brunei Darussalam' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cabo Verde'
#  'Cambodia' 'Cameroon' 'Canada' 'Cayman Islands'
#  'Central African Republic' 'Chad' 'Channel Islands' 'Chile' 'China'
#  'Colombia' 'Comoros' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia' 'Denmark'
#  'Djibouti' 'Dominica' 'Dominican Republic' 'Ecuador' 'Egypt, Arab Rep.'
#  'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini'
#  'Ethiopia' 'Faroe Islands' 'Fiji' 'Finland' 'France' 'French Polynesia'
# ...

# %%
# Cuadro de resumen estadistico

df.describe(include= 'all').round()
# Out:
#                Pais Pais_Cod     Anio Anio_Cod  \
# count         17024    17024  17024.0    17024
# unique          266      266      NaN       64
# top     Afghanistan      AFG      NaN   YR1960
# freq             64       64      NaN      266
# mean            NaN      NaN   1992.0      NaN
# std             NaN      NaN     18.0      NaN
# min             NaN      NaN   1960.0      NaN
# 25%             NaN      NaN   1976.0      NaN
# 50%             NaN      NaN   1992.0      NaN
# 75%             NaN      NaN   2007.0      NaN
# max             NaN      NaN   2023.0      NaN
#
#         Acceso a Cocina Limpia (% poblacion)  \
# count                                 5214.0
# unique                                   NaN
# top                                      NaN
# freq                                     NaN
# mean                                    62.0
# std                                     38.0
# min                                      0.0
# ...

# %% [markdown]
# Viendo los registros, veo que los registros correspondientes al año 2023 tiene todos sus valores nulos, por lo que voy a descartar ese registro de mi df con el método drop

# %%
df.drop(df[df['Anio'] == 2023].index, inplace=True)

# %%
df.head(65)
# Out:
#            Pais Pais_Cod  Anio Anio_Cod  Acceso a Cocina Limpia (% poblacion)  \
# 0   Afghanistan      AFG  1960   YR1960                                   NaN
# 1   Afghanistan      AFG  1961   YR1961                                   NaN
# 2   Afghanistan      AFG  1962   YR1962                                   NaN
# 3   Afghanistan      AFG  1963   YR1963                                   NaN
# 4   Afghanistan      AFG  1964   YR1964                                   NaN
# ..          ...      ...   ...      ...                                   ...
# 60  Afghanistan      AFG  2020   YR2020                                  33.8
# 61  Afghanistan      AFG  2021   YR2021                                  35.4
# 62  Afghanistan      AFG  2022   YR2022                                   NaN
# 64      Albania      ALB  1960   YR1960                                   NaN
# 65      Albania      ALB  1961   YR1961                                   NaN
#
# ...

# %%
# Ahora voy a establece las columnas 'Pais_Cod' y 'Anio_Cod' como índices
df = df.set_index(['Pais_Cod', 'Anio_Cod'])

# %% [markdown]
# # Visualización de datos

# %% [markdown]
# ### Primeras visualizaciones.
#
# Haré una visualización gráfica que me permita explorar algunas correlaciones sencillas, principalmente para ver si los datos están bien.
#
# Por ejemplo, cómo es la relación entre el crecimiento demográfico (población), las áreas de bosques y las emisiones de gases de efecto invernadero?

# %%
# Aplico un pairplot para ver correlaciones, pero solo para la entidad mundo ('World')

# Filtrar el DataFrame para 'mundo'
df_world = df[df['Pais'] == 'World']


# Crear un pairplot para df_mundo
sns.pairplot(df_world, vars=['Poblacion Total', 'Area de Bosque (% area terrestre)', 'Emisiones Totales de Gases de Efecto Invernadero (kton CO2eq)'])

# Mostrar el gráfico
plt.show()
# Out:
# /home/karim/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/karim/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/karim/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Respondiendo a la pregunta anterior a partir de esta visualiación, podemos decir que hay una relación negativa entre población y areas de bosques, o sea, a medida que ha ido creciendo la población del mundo, se han ido reduciendo las areas de bosques.
#
# En cambio parece haber una relación positiva entre población y gases de efecto invernadero, o sea, a medida que crece la población, crece tanbién la generación de gases de efecto invernadero.
#
# Es importante destacar aquí, que es anticipado decir que la correlación es causal (o sea que una variable está causando otra), sólo podemos inferir correlación. Será necesario seguir investigando para ver si efectivamente hay una causalidad directa.

# %% [markdown]
# Vamos ahora a entrar en lo central de este trabajo, que es responder:
#
# # **Cómo ha cambiado el mundo en 60 años?**

# %% [markdown]
# ### **Población**
#
# Uno de los puntos más importantes del cambio global de los últimos 60 años, ha sido el incremento de la población total a nivel mundial. Pues la población del mundo había tenido una cierta calma y crecimiento gradual durante muchos siglos, sin embargo el crecimiento humano durante el siglo XXI se volvió exponensial. Vamos a visualizar cómo ha sido ese crecimiento para entenderlo mejor.

# %%
# Filtrar el DataFrame para el subgrupo 'World'
#df_world = df[df['pais'] == 'World']

# Crear un gráfico de líneas para la población
plt.plot(df_world['Anio'], df_world['Poblacion Total'])

# Configurar el título y las etiquetas de los ejes
plt.title('Aumento de la población mundial')
plt.xlabel('Año')
plt.ylabel('Población (miles de millones)')

# Mostrar el gráfico
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Puede verse un significativo aumento desde unos 3 mil millones de personas en el 1960 a alrededor de 8 mil millones en 2020.
#
# Vamos a ver las cifras exactas a continuación:

# %%
# Valores poblacionales mínimo y máximo

pob_min = int(df_world['Poblacion Total'].min())
pob_max = int(df_world['Poblacion Total'].max())

print(f'los valores mínimos y máximos graficados anteriormente son: mínimo = {pob_min} máximo = {pob_max}')
# Out:
# los valores mínimos y máximos graficados anteriormente son: mínimo = 3031474234 máximo = 7950946801

# %% [markdown]
# Ahora veamos cómo se ha dado este explosivo crecimiento, ha sido similar en todo el mundo o hay zonas de mayor crecimiento que otras. Una forma de ver esto es hacer un primer desgloce por continentes.
#
# Para esto haré una modificación en el DF, primero crearé la columna 'continente' y luego aplicaré el MERGE para fusionarlo con el DF

# %%
# Segmentación por continentes:

africa = ['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cameroon', 'Chad', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.', "Cote d'Ivoire", 'Djibouti', 'Egypt, Arab Rep.', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'Gambia, The', 'Ghana', 'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa', 'South Sudan', 'Sudan', 'Tanzania', 'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe']

asia = ['Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Bhutan', 'Brunei Darussalam', 'Cambodia', 'China', 'Cyprus', 'Georgia', 'Hong Kong SAR, China', 'India', 'Indonesia', 'Iran, Islamic Rep.', 'Iraq', 'Israel', 'Japan', 'Jordan', 'Kazakhstan', 'Korea, Dem. People\'s Rep.', 'Korea, Rep.', 'Kuwait', 'Kyrgyz Republic', 'Lao PDR', 'Lebanon', 'Malaysia', 'Maldives', 'Mongolia', 'Myanmar', 'Nepal', 'Oman', 'Pakistan', 'Philippines', 'Qatar', 'Saudi Arabia', 'Singapore', 'Sri Lanka', 'Syrian Arab Republic', 'Tajikistan', 'Thailand', 'Timor-Leste', 'Turkey', 'Turkmenistan', 'United Arab Emirates', 'Uzbekistan', 'Viet Nam', 'Yemen, Rep.']

europa = ['Albania', 'Andorra', 'Austria', 'Belarus', 'Belgium', 'Bosnia and Herzegovina', 'Bulgaria', 'Channel Islands', 'Croatia', 'Czechia', 'Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'France', 'Germany', 'Gibraltar', 'Greece', 'Greenland', 'Hungary', 'Iceland', 'Ireland', 'Isle of Man', 'Italy', 'Kosovo', 'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta', 'Moldova', 'Monaco', 'Montenegro', 'Netherlands', 'North Macedonia', 'Norway', 'Poland', 'Portugal', 'Romania', 'Russian Federation', 'San Marino', 'Serbia', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Ukraine', 'United Kingdom', 'Vatican City']

oceania = ['American Samoa', 'Australia', 'Fiji', 'French Polynesia', 'Guam', 'Kiribati', 'Marshall Islands', 'Micronesia, Fed. Sts.', 'Nauru', 'New Caledonia', 'New Zealand', 'Palau', 'Papua New Guinea', 'Samoa', 'Solomon Islands', 'Tonga', 'Tuvalu', 'Vanuatu']

norteamerica = ['Canada', 'United States', 'Mexico']

sudamerica = ['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela, RB']

centroamerica_caribe = ['Antigua and Barbuda', 'Aruba', 'Bahamas, The', 'Barbados', 'Belize', 'Bermuda', 'British Virgin Islands', 'Cayman Islands', 'Costa Rica', 'Cuba', 'Curacao', 'Dominica', 'Dominican Republic', 'El Salvador', 'Grenada', 'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Nicaragua', 'Panama', 'Puerto Rico', 'St. Kitts and Nevis', 'St. Lucia', 'St. Martin (French part)', 'St. Vincent and the Grenadines', 'Trinidad and Tobago', 'Turks and Caicos Islands', 'Virgin Islands (U.S.)']


# Creo un diccionario con los nombres de los continentes como claves y las listas de países como valores
continentes = {
    'Africa': africa,
    'Asia': asia,
    'Europa': europa,
    'Oceanía': oceania,
    'América del Norte': norteamerica,
    'América del Sur': sudamerica,
    'América Central y el Caribe': centroamerica_caribe
}

# Convertir el diccionario en un DataFrame
df_continentes = pd.DataFrame([(pais, continente) for continente, paises in continentes.items() for pais in paises],
                               columns=['Pais', 'Continente'])

# %%
# Combino df con df_continentes usando la columna 'Pais'
df_continentes = pd.merge(df, df_continentes, on='Pais', how='left')

df_continentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16758 entries, 0 to 16757
# Data columns (total 62 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Pais                                                                            16758 non-null  object
#  1   Anio                                                                            16758 non-null  int64
#  2   Acceso a Cocina Limpia (% poblacion)                                            5214 non-null   float64
#  3   Acceso a Electricidad (% poblacion)                                             7348 non-null   float64
#  4   Tierra Agricola Irrigada (% tierra agricola)                                    1056 non-null   float64
#  5   Tierra Agricola (% area terrestre)                                              14714 non-null  float64
# ...

# %%
'''
Comparación crecimiento población entre continentes. 1960-2022
'''
# Agrupar por continente y año y sumar la población total
poblacion_continente_anio = df_continentes.groupby(['Continente', 'Anio'])['Poblacion Total'].sum().reset_index()

# %%
# Crear un gráfico de líneas con la población a lo largo del tiempo para cada continente
plt.figure(figsize=(10, 6))
sns.lineplot(data=poblacion_continente_anio, x="Anio", y="Poblacion Total", hue="Continente")
plt.title('Crecimiento de la población en los continentes (1965-2022)')
plt.xlabel('Año')
plt.ylabel('Población')
plt.show()
# Out:
# /home/karim/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/karim/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Acá podemos ver algo muy interesante! no todos los continentes han experimentado un aumento tan radical de crecimiento poblacional. Sin embargo, Asia es quien ha tenido un crecimiento mayor que todos los otros continentes. Cómo se vería la situación si exploramos dentro de Asia, cómo se ha distribuído el creicimiento entre sus países?

# %%
# Filtrar el dataframe para el continente de Asia
df_asia = df[df['Pais'].isin(asia)]

# Seleccionar los últimos valores disponibles de población
df_asia_latest = df_asia.groupby('Pais')['Poblacion Total'].last().sort_values(ascending=False)

# Crear un gráfico de barras con colores distintos para cada país
plt.figure(figsize=(20, 6))
sns.barplot(x=df_asia_latest.index, y=df_asia_latest.values, palette='bright')
plt.title('Distribución de la población en Asia')
plt.xlabel('País')
plt.ylabel('Población')
plt.xticks(rotation=90)  # Rotar etiquetas del eje x para mejor visualización
plt.show()

# %% [markdown]
# Aquí estamos viendo cómo es actualmente la distribución de la población en Asia, con esto podríamos afirmar, que no solo es Asia el continente que tiene un mayor crecimiento poblacional, si no que dentro de Asia mismo, son principalmente los países de India y Chila los que más influencia tienen en el crecimiento.
#
# Una idea interesante para enriquecer este DF en relación a la población mundial, podría ser descargar desde la API de World Bank la estimaciones de población proyectadas para los próximos años.

# %% [markdown]
# ## **ACÁ AUN FALTA POR EXPLORAR MAS**

# %% [markdown]
# # **Data Wrangling**
# ### **Enriquecimiento de los datos**
# Si bien el concepto de Data Wrangling alude al proceso de limpiar, estructurar y enriquecer conjuntos de datos desorganizados o crudos para hacerlos más accesibles y útiles para análisis posteriores y es proceso es fundamental en el análisis de datos. En esta ocasión lo usaremos como referencia al proceso de enriquecimiento de los datos, através del proceso de consulta a la API del World Bank.
#
# Si bien el World Bank tiene su propia documentación sobre el uso de la API (https://datahelpdesk.worldbank.org/knowledgebase/topics/125589-developer-information), encontré un tutorial bastante didáctico que me sirvió para realizar este proceso en:
#         https://deepnote.com/app/carlos-mendez/PYTHON-World-Bank-data-7d57b121-2bdf-4f13-b8d9-9520c9f8a7cc
#
# A continuación mostraré algunas de las acciones que pueden realizarse con python y la librería del World Bank API.

# %%
'''
Importo la librería necesaria para usar esta API (en la mayoría de los casos será necesario instalarla ante de importarla)

Observación: Es buena práctica importar todas las librerías al comienzo, pero decidí importarla en este punto para hacer el ejercicio de consulta a la API más claro.
''' 

# Libreria the World Bank API
import wbgapi as wb

# %%
# Consulto cómo solicitar la info de la API

help(wb.data.DataFrame)
# Out:
# Help on function DataFrame in module wbgapi.data:
#
# DataFrame(series, economy='all', time='all', index=None, columns=None, mrv=None, mrnev=None, skipBlanks=False, labels=False, skipAggs=False, numericTimeKeys=False, timeColumns=False, params={}, db=None, **dimensions)
#     Retrieve a 2-dimensional pandas dataframe.
#
#     Arguments:
#         series:             a series identifier or list-like, e.g., SP.POP.TOTL
#
#         economy:            an economy identifier or list-like, e.g., 'BRA' or ['USA', 'CAN', 'MEX']
#
#         time:               a time identifier or list-like, e.g., 'YR2015' or range(2010,2020).
#                             Both element keys and values are acceptable
#
#         index:              name or list of dimensions for the DataFrame's index, e.g., 'economy'. If None then the function
#                             will define the index based on your request. Note: to get a dataframe with no index
# ...

# %%
# Consulto los temas disponibles

wb.topic.info()
# Out:
# id    value
# ----  -------------------------------
# 1     Agriculture & Rural Development
# 2     Aid Effectiveness
# 3     Economy & Growth
# 4     Education
# 5     Energy & Mining
# 6     Environment
# 7     Financial Sector
# 8     Health
# 9     Infrastructure
# 10    Social Protection & Labor
# 11    Poverty
# 12    Private Sector
# 13    Public Sector
# 14    Science & Technology
# 15    Social Development
# 16    Urban Development
# 17    Gender
# 18    Millenium development goals
# 19    Climate Change
# 20    External Debt
# 21    Trade
#       21 elements

# %%
'''
Ya que tengo interés en explorar cómo se ha transformado el mundo en 60 años, voy a explorar el temas de  "Climate Change"(19) 
'''

# Consulto las variables (series) disponibles en Climate Change
wb.series.info(topic = 19)
# Out:
# id                    value
# --------------------  ------------------------------------------------------------------------------------------
# EG.ELC.ACCS.ZS        Access to electricity (% of population)
# AG.LND.IRIG.AG.ZS     Agricultural irrigated land (% of total agricultural land)
# AG.LND.AGRI.ZS        Agricultural land (% of land area)
# AG.LND.AGRI.K2        Agricultural land (sq. km)
# NV.AGR.TOTL.ZS        Agriculture, forestry, and fishing, value added (% of GDP)
# ER.H2O.FWTL.ZS        Annual freshwater withdrawals, total (% of internal resources)
# ER.H2O.FWTL.K3        Annual freshwater withdrawals, total (billion cubic meters)
# AG.LND.ARBL.ZS        Arable land (% of land area)
# AG.LND.PRCP.MM        Average precipitation in depth (mm per year)
# AG.YLD.CREL.KG        Cereal yield (kg per hectare)
# EN.ATM.CO2E.KD.GD     CO2 emissions (kg per 2015 US$ of GDP)
# EN.ATM.CO2E.PP.GD.KD  CO2 emissions (kg per 2017 PPP $ of GDP)
# ...

# %%
'''
Para entender mejor cada una de estas series, puedo consultar su metadata que proporciona información más detallada
'''

# Consulta por el indicador de "Population, total"

wb.series.metadata.get('SP.POP.TOTL')
# Out:
# ...
# Series: SP.POP.TOTL
#
# Aggregationmethod: Sum
# --------
# Developmentrelevance: Increases in human population, whether as a result of immigration or more births than deaths, can impact natural resources and social infrastructure.  This can place pressure on a country's sustainability.  A significant growth in population will negatively impact the availability of land for agricultural production, and will aggravate demand for food, energy, water, social services, and infrastructure. On the other hand, decreasing population size - a result of fewer births than deaths, and people moving out of a country - can impact a government's commitment to maintain services and infrastructure.
# --------
# Generalcomments: Relevance to gender indicator: disaggregating the population composition by gender will help a country in projecting its demand for social services on a gender basis.
# --------
# IndicatorName: Population, total
# --------
# License_Type: CC BY-4.0
# --------
# ...

# %% [markdown]
# A continuación, voy a usar la información con la función de gráficos, para tener una **visualización**, en este caso la usaré para enriquecer el entendimiento del gráfico anterior sobre población de Asia. En ese gráfico, aparecián los paises de China, India e Indonesia como los de mayor población en Asia. Vamos a explorar cómo sucedió ese crecimiento demográfico desde el año 1960 hasta la actualidad.

# %%
# consulto el indicados de población total, lo segmento a China, India e Indonesia, y aplico el rango de tiempo de 1960-2022

wb.data.DataFrame('SP.POP.TOTL',
       ['CHN', 'IND', 'IDN'],
       time=range(1960,2022)).T.plot();

# %% [markdown]
# Aquí puede verse que Indonesia ha tenido un crecimiento bastante más regulado que China e India. Además, parece haber una ligera disminución del crecimiento de China en contraste de un mayor aumento de India.
#
# Sería interesante explorar las proyecciones futuras de crecimiento de la población para analizar cómo será la tendencia de crecimiento demográfico de estos países en los próximos años y analizar cómo esto podría impactar en la transformación del mundo para el s. XXI.

# %%
# Consulta por el indicador de "Forest Area"


wb.series.metadata.get('AG.LND.FRST.ZS')
# Out:
# ...
# Series: AG.LND.FRST.ZS
#
# Aggregationmethod: Weighted average
# --------
# Developmentrelevance: As threats to biodiversity mount, the international community is increasingly focusing on conserving diversity. Deforestation is a major cause of loss of biodiversity, and habitat conservation is vital for stemming this loss. Conservation efforts have focused on protecting areas of high biodiversity.
#
# On a global average, more than one-third of all forest is primary forest, i.e. forest of native species where there are no clearly visible indications of human activities and the ecological processes have not been significantly disturbed. Primary forests, in particular tropical moist forests, include the most species-rich, diverse terrestrial ecosystems. The decrease of forest area, .11 percent over a ten-year period, is largely due to reclassification of primary forest to "other naturally regenerated forest" because of selective logging and other human interventions.
#
# ...

# %% [markdown]
# Traduzco para que se entienda el indicador:
#
# A medida que las amenazas a la biodiversidad aumentan, la comunidad internacional está enfocándose cada vez más en conservar la diversidad. La deforestación es una causa principal de pérdida de biodiversidad, y la conservación del hábitat es vital para detener esta pérdida. Los esfuerzos de conservación se han centrado en proteger áreas de alta biodiversidad. En promedio mundial, más de un tercio de todo el bosque es bosque primario, es decir, bosque de especies nativas donde no hay indicaciones claramente visibles de actividades humanas y los procesos ecológicos no han sido significativamente perturbados. Los bosques primarios, en particular los bosques húmedos tropicales, incluyen los ecosistemas terrestres más ricos en especies y diversos. La disminución del área forestal, del 0,11 por ciento en un período de diez años, se debe en gran medida a la reclasificación de bosques primarios como "otros bosques regenerados naturalmente" debido a la tala selectiva y otras intervenciones humanas. La destrucción de los bosques tropicales sigue siendo un problema ambiental significativo. Gran parte de lo que queda de los bosques tropicales del mundo está en la cuenca del Amazonas, donde la selva amazónica cubre aproximadamente 4 millones de kilómetros cuadrados. Las regiones con la tasa más alta de deforestación tropical están en América Central y Asia tropical. La FAO estima que la disminución del área de bosque primario, del 0,4 por ciento en un período de diez años, se debe en gran medida a la reclasificación de bosques primarios como "otros bosques regenerados naturalmente" debido a la tala selectiva y otras intervenciones humanas. La plantación a gran escala de árboles está reduciendo significativamente la pérdida neta de área forestal a nivel mundial, y la forestación y la expansión natural de los bosques en algunos países y regiones han reducido la pérdida neta de área forestal de manera significativa a nivel mundial. Los bosques cubren aproximadamente el 31 por ciento del área terrestre total del mundo; el área forestal total del mundo es un poco más de 4 mil millones de hectáreas. En promedio mundial, más de un tercio de todo el bosque es bosque primario, es decir, bosque de especies nativas donde no hay indicaciones claramente visibles de actividades humanas y los procesos ecológicos no han sido significativamente perturbados. Los parques nacionales, reservas de caza, áreas silvestres y otras áreas protegidas legalmente establecidas cubren más del 10 por ciento del área forestal total en la mayoría de los países y regiones. La FAO estima que alrededor de 10 millones de personas trabajan en la gestión y conservación forestal, pero muchas más dependen directamente de los bosques para sus medios de vida. Cerca de 1,2 mil millones de hectáreas de bosque se gestionan principalmente para la producción de productos forestales madereros y no madereros. Un 25 por ciento adicional del área forestal está designado para múltiples usos, en la mayoría de los casos, incluida la producción de productos forestales madereros y no madereros. El área designada principalmente para fines productivos ha disminuido en más de 50 millones de hectáreas desde 1990, ya que los bosques han sido designados para otros propósitos.

# %% [markdown]
# ### Veamos cómo ha variado el área de bosques a nivel mundial desde 1960 a 2022

# %%
# Ahora grafico el % de Forest Area

wb.data.DataFrame('AG.LND.FRST.ZS',
       ['WLD'],
       time=range(1960,2022)).T.plot();

# %% [markdown]
# Observaciones: Si bien se ve una marcada tendencia hacia una disminución del % de áreas de bosque en el mundo, es importante notar (del gráfico anterior), que los datos son sólo de 1995 a 2020 (exploraré si hay datos anteriores a 1995) y que la disminución si bien se ve muy significativa, es de solo un punto porcentual aprox. (de 32.4% a 31.2%).

# %% [markdown]
# Con esto, dejaré hasta aquí la sección del data wrangling, para volver a trabajar directamente sobre mi Dataset, de ser necesario iteraré entre consultas entre mi base de datos y la API del World Bank
#
# ---------------------------------

# %%
'''
Vamos a hacer lo mismo que el gráfico anterior, pero ahora con la variable de KM2 (kilómetros cuadrados)
'''

# Crear un gráfico de línea para mostrar la evolución en el tiempo del % de área de bosque
sns.lineplot(data=df_world, x='Anio', y='Area de Bosque (km2)')

# Añadir etiquetas y título al gráfico
plt.xlabel('Año')
plt.ylabel('Kilometros cuadrados de Área de Bosque')
plt.title('Evolución los KM2 de Bosque en el Mundo')

# Mostrar el gráfico
plt.show()
# Out:
# /home/karim/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/karim/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
'''
Comparación entre continentes de la reducción de KM2 de áreas de bosque
'''
# Agrupar por continente y año y sumar los km2 de bosque
poblacion_continente_anio = df_continentes.groupby(['Continente', 'Anio'])['Area de Bosque (km2)'].sum().reset_index()


# Crear un gráfico de líneas con la población a lo largo del tiempo para cada continente
plt.figure(figsize=(10, 6))
sns.lineplot(data=poblacion_continente_anio, x="Anio", y='Area de Bosque (km2)', hue="Continente")
plt.title('Variación de los km2 de área de bosque entre continentes')
plt.xlabel('Año')
plt.ylabel('KM2 Área Bosque')
plt.show()
# Out:
# /home/karim/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/karim/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Observaciones: El gráfico no se ve bien pues al parecer está tomomando los valores perdidos como 0 y por lo tanto agregandolos a la visualización (probaré expluyendo el valor 0). Además, consultaré en la API, cuál es el formato del valor medido en los KM2.

# %%
# Agrupar por continente y año y sumar los km2 de bosque
km_continente_anio = df_continentes.groupby(['Continente', 'Anio'])['Area de Bosque (km2)'].sum().reset_index()

# Filtrar los registros con valores mayores a 0 en 'Area de Bosque (km2)'
km_continente_anio = km_continente_anio[poblacion_continente_anio['Area de Bosque (km2)'] > 0]

# Crear un gráfico de líneas con la población a lo largo del tiempo para cada continente
plt.figure(figsize=(10, 6))
sns.lineplot(data=km_continente_anio, x="Anio", y='Area de Bosque (km2)', hue="Continente")
plt.title('Variación de los km2 de área de bosque entre continentes')
plt.xlabel('Año')
plt.ylabel('KM2 Área Bosque')
plt.legend(title='Continente', loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
# Out:
# /home/karim/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/karim/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Observaciones: Estimo que debe haber un error en los valores iniciales de "Europa", pues es extraño que tenga una subida tan abrupta.

# %%
'''
Voy a consultar por este indicador en la API, para entender mejor cómo interpretarlo
'''
# Busco el código de la variable en la lista de arriba y lo consulto

wb.series.metadata.get('AG.LND.FRST.K2')
# Out:
# ...
# Series: AG.LND.FRST.K2
#
# Aggregationmethod: Sum
# --------
# Developmentrelevance: As threats to biodiversity mount, the international community is increasingly focusing on conserving diversity. Deforestation is a major cause of loss of biodiversity, and habitat conservation is vital for stemming this loss. Conservation efforts have focused on protecting areas of high biodiversity.
#
# On a global average, more than one-third of all forest is primary forest, i.e. forest of native species where there are no clearly visible indications of human activities and the ecological processes have not been significantly disturbed. Primary forests, in particular tropical moist forests, include the most species-rich, diverse terrestrial ecosystems. The decrease of primary forest area, 0.4 percent over a ten-year period, is largely due to reclassification of primary forest to "other naturally regenerated forest" because of selective logging and other human interventions.
#
# ...

# %% [markdown]
# Uso ChatGPT para hacer el siguiente resumen:
#
# **Serie:** AG.LND.FRST.K2
#
# **Método de agregación:** Suma
#
# **Relevancia para el desarrollo:**
# - La deforestación es una causa principal de pérdida de biodiversidad, y la conservación de hábitats es vital. Los bosques primarios representan más de un tercio de todos los bosques y son ricos en biodiversidad. Sin embargo, están disminuyendo en un 0.4% en diez años debido a la intervención humana.
# - Las áreas protegidas cubren más del 10% del área total de bosques en la mayoría de los países. Alrededor de 10 millones de personas trabajan en la gestión y conservación de bosques.
# - El 80% de los bosques son de propiedad pública, aunque la gestión privada está en aumento.
# - 1.2 mil millones de hectáreas de bosque se gestionan principalmente para la producción de madera y otros productos forestales.
#
# **Nombre del indicador:** Área de bosque (km²)
#
# **Tipo de licencia:** CC BY-4.0
#
# **URL de la licencia:** [https://datacatalog.worldbank.org/public-licenses#cc-by](https://datacatalog.worldbank.org/public-licenses#cc-by)
#
# **Limitaciones y excepciones:**
# - La FAO ha estado recopilando datos sobre el área forestal desde 1946, actualizándolos cada 5-10 años como parte de la Evaluación de Recursos Forestales Globales (FRA). Los datos abarcan 229 países y territorios. Las áreas deforestadas no incluyen áreas taladas destinadas a regeneración.
# - Los datos incluyen bosques con bambú, palmas, áreas abiertas pequeñas, y bosques en parques nacionales y otras áreas protegidas. Excluyen árboles en sistemas agrícolas y urbanos.
#
# **Definición larga:**
# - Área de bosque se refiere a tierras con rodales de árboles naturales o plantados de al menos 5 metros de altura, excluyendo sistemas de producción agrícola y áreas urbanas.
#
# **Otras notas:**
# - Las series agregadas mundiales y regionales no incluyen datos de países que ya no existen.
#
# **Periodicidad:** Anual
#
# **Fuente:**
# - Organización de las Naciones Unidas para la Agricultura y la Alimentación (FAO), archivos electrónicos y sitio web.
#
# **Concepto y metodología estadística:**
# - La definición de bosque incluye áreas bajo reforestación que se espera alcancen una cobertura arbórea del 10% y una altura de 5 metros. La FAO proporciona información detallada sobre la cobertura forestal, aunque la estimación de deforestación puede subestimar la pérdida de bosques naturales en algunos países.
#
# **Tema:** Medio ambiente: Uso de la tierra

# %% [markdown]
# Si bien la información anterior es muy interesante para entender la importancia de este indicador y cómo se entiende. En el texto no aparece la unidad de medida, por lo que consulto el siguente link:
#
# https://data.worldbank.org/indicator/AG.LND.FRST.K2
#
# Acá encuentro el mismo gráfico que elaboré usando los datos segmentados por "Mundo" y aparece la unidad de medida. Es millones de KM2!!
#
# Usaré la siguiente celda de código para seguir la interpretación.

# %%
# valor máximo de la variable "km2 bosque"
max_km_bosque = round(df_world['Area de Bosque (km2)'].max())

# valor mínimo de la variable "km bosque"
min_km_bosque = round(df_world['Area de Bosque (km2)'].min())

# Diferencia entre max y min.
res_km_bosque = round(max_km_bosque - min_km_bosque)

# Redondié todos los valores para que el resultado se vea más limpio

# Imprimo con interpretación incluida.
print(f"A nivel mundial, pasamos de {max_km_bosque} (42 millones de km2 de áreas de bosques) a {min_km_bosque} (40 millones de km2), esto es una disminución de {res_km_bosque} (1.5 millones de km2) en un rango de 25 años")
# Out:
# A nivel mundial, pasamos de 42034237 (42 millones de km2 de áreas de bosques) a 40449475 (40 millones de km2), esto es una disminución de 1584762 (1.5 millones de km2) en un rango de 25 años

# %%
# Agrupa por país y encuentra el máximo y mínimo de área de bosques para cada país
max_area_bosques = df.groupby('Pais')['Area de Bosque (km2)'].max()
min_area_bosques = df.groupby('Pais')['Area de Bosque (km2)'].min()

# Calcula la disminución de área de bosques restando el máximo al mínimo para cada país
disminucion_bosques = max_area_bosques - min_area_bosques

# Ordena los países por la disminución de área de bosques en orden descendente
top_3_disminucion = disminucion_bosques.sort_values(ascending=False).head(3)

# Convierte la serie resultante en un DataFrame para facilitar la visualización
top_3_disminucion_df = top_3_disminucion.reset_index()

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.bar(top_3_disminucion_df['Pais'], top_3_disminucion_df['Area de Bosque (km2)'], color='skyblue')
plt.xlabel('País')
plt.ylabel('Disminución de Área de Bosques (km²)')
plt.title('Top 3 Países con Mayor Disminución de Área de Bosques')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Observación: No es el resultado que esperaba pues veo que al estar mezclados paises y entidades que no son países, se ensucia el resultado. Debo generar listas que me permitan consultar de forma separada paises y/o entidades.
